# %%
import pandas as pd

# %%
nat_baby_names = pd.read_csv('NationalNames.csv')
state_baby_names = pd.read_csv('StateNames.csv')
race_names = pd.read_csv('wiki_name_race.csv')

# %%
nat_baby_names['Name'] = nat_baby_names['Name'].str.lower()
nat_baby_names.head(5)
# Out:
#    Id       Name  Year Gender  Count
# 0   1       mary  1880      F   7065
# 1   2       anna  1880      F   2604
# 2   3       emma  1880      F   2003
# 3   4  elizabeth  1880      F   1939
# 4   5     minnie  1880      F   1746

# %%
state_baby_names['Name'] = state_baby_names['Name'].str.lower()
state_baby_names.head(5)
# Out:
#    Id      Name  Year Gender State  Count
# 0   1      mary  1910      F    AK     14
# 1   2     annie  1910      F    AK     12
# 2   3      anna  1910      F    AK     10
# 3   4  margaret  1910      F    AK      8
# 4   5     helen  1910      F    AK      7

# %%
race_names = race_names[['name_first', 'race']]
race_names.head(5)
# Out:
#          name_first                                   race
# 0             aafje  GreaterEuropean,WestEuropean,Germanic
# 1            aaltje  GreaterEuropean,WestEuropean,Germanic
# 2             abbie  GreaterEuropean,WestEuropean,Germanic
# 3  abbo of provence  GreaterEuropean,WestEuropean,Germanic
# 4         abdelaziz  GreaterEuropean,WestEuropean,Germanic

# %%
name_race_counts = race_names.groupby(['name_first', 'race']).size().reset_index(name='counts_name_race')

name_totals_df = name_race_counts.groupby(['name_first'])['counts_name_race'].sum().to_frame().reset_index()
name_totals_df
name_totals_df['counts_name'] = name_totals_df['counts_name_race']
name_totals_df = name_totals_df[['name_first', 'counts_name']]

counts_name_race = pd.merge(name_race_counts, name_totals_df, on=['name_first', 'name_first'])
counts_name_race.head()
# Out:
#    name_first                                   race  counts_name_race  \
# 0        'abd                  GreaterAfrican,Muslim                 2
# 1     'gbenga                GreaterAfrican,Africans                 1
# 2        'h'.                GreaterEuropean,British                 1
# 3  'horrible'                GreaterEuropean,British                 1
# 4          't  GreaterEuropean,WestEuropean,Germanic                 1
#
#    counts_name
# 0            2
# 1            1
# 2            1
# 3            1
# 4            1

# %%
counts_name_race['racial_proportion'] = counts_name_race['counts_name_race'] / counts_name_race['counts_name']
counts_name_race = counts_name_race.sort_values(by=['counts_name'], ascending=False)
counts_name_race.head(20)
# Out:
#       name_first                                   race  counts_name_race  \
# 21199       john       Asian,GreaterEastAsian,EastAsian                38
# 21206       john                 GreaterEuropean,Jewish                77
# 21208       john  GreaterEuropean,WestEuropean,Germanic                20
# 21209       john  GreaterEuropean,WestEuropean,Hispanic                35
# 21210       john   GreaterEuropean,WestEuropean,Italian               115
# 21211       john    GreaterEuropean,WestEuropean,Nordic                42
# 21205       john           GreaterEuropean,EastEuropean                15
# 21204       john                GreaterEuropean,British              2263
# 21203       john                  GreaterAfrican,Muslim                 9
# 21202       john                GreaterAfrican,Africans                26
# 21201       john               Asian,IndianSubContinent                25
# 21200       john        Asian,GreaterEastAsian,Japanese                11
# 21207       john    GreaterEuropean,WestEuropean,French               121
# 44947    william                  GreaterAfrican,Muslim                 4
# 44946    william                GreaterAfrican,Africans                13
# 44945    william               Asian,IndianSubContinent                 4
# 44944    william        Asian,GreaterEastAsian,Japanese                 4
# 44943    william       Asian,GreaterEastAsian,EastAsian                20
# 44955    william    GreaterEuropean,WestEuropean,Nordic                11
# 44951    william    GreaterEuropean,WestEuropean,French               114
#
#        counts_name  racial_proportion
# 21199         2797           0.013586
# 21206         2797           0.027529
# 21208         2797           0.007151
# 21209         2797           0.012513
# 21210         2797           0.041115
# 21211         2797           0.015016
# 21205         2797           0.005363
# 21204         2797           0.809081
# 21203         2797           0.003218
# 21202         2797           0.009296
# 21201         2797           0.008938
# 21200         2797           0.003933
# 21207         2797           0.043261
# 44947         1600           0.002500
# 44946         1600           0.008125
# 44945         1600           0.002500
# 44944         1600           0.002500
# 44943         1600           0.012500
# 44955         1600           0.006875
# 44951         1600           0.071250

# %%
counts_name_race.to_csv('first_name_racial_proportions.csv')
